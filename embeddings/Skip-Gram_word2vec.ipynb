# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:13, 2.27MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
## Compute frequencies
from collections import Counter
freq=Counter(int_words)
length = len(int_words)
treshold=1e-5
train_words = []# The final subsampled word list
for i in int_words:
    pdiscard =1.0-np.sqrt(treshold*length/freq[i])
    if np.random.rand()>pdiscard:
        train_words.append(i)
print(int_words[:100])
print(train_words[:100])
# Out:
# [5239, 3082, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10625, 133, 0, 27435, 1, 0, 102, 854, 2, 0, 15103, 59045, 1, 0, 150, 854, 3582, 0, 194, 10, 190, 58, 4, 5, 10751, 214, 6, 1325, 104, 454, 19, 58, 2732, 362, 6, 3676, 0, 708, 1, 371, 26, 40, 36, 53, 540, 97, 11, 5, 1423, 2757, 18, 567, 686, 7091, 0, 247, 5239, 10, 1052, 27, 0, 320, 248, 46089, 2879, 792, 186, 5239, 11, 5, 200, 602, 10, 0, 1136, 19, 2622, 25, 8985, 2, 279, 31, 4147, 141, 59, 25, 6444]
# [5239, 3133, 10625, 133, 27435, 15103, 59045, 3582, 10751, 1325, 2732, 371, 40, 1423, 567, 7091, 247, 46089, 5239, 1136, 2622, 8985, 362, 5239, 1818, 4865, 6768, 7584, 1775, 566, 247, 11082, 5953, 4870, 20546, 55264, 25790, 7584, 371, 7584, 15229, 1775, 7091, 4865, 5695, 4336, 1536, 8138, 5239, 26, 155, 7091, 8183, 153, 31, 246, 4778, 2314, 8405, 310, 8066, 24585, 19, 1032, 4778, 8147, 24585, 2, 12779, 6143, 4194, 21275, 2427, 16564, 7243, 10250, 15083, 187, 913, 12321, 7091, 133, 11082, 12117, 734, 14681, 485, 24585, 20045, 20387, 57286, 24585, 20387, 16488, 30364, 44, 54581, 3817, 3415, 1781]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = np.random.randint(1,window_size+1) 
    if (idx-r) > 0:
        start = idx-r
    else:
        start=0
            
    if(idx+r)<len(words):
        stop = idx+r
    else:    
        stop = len(words)-1
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab,n_embedding),minval=-1,maxval=1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random_normal(shape=(n_vocab,n_embedding)),dtype=tf.float32)# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(shape=(n_vocab)),dtype=tf.float32)# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 20.1846 0.0550 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 20.0088 0.0507 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 19.7594 0.0510 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 19.6042 0.0509 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 19.4369 0.0509 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 19.3321 0.0508 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 19.2599 0.0511 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 19.0841 0.0509 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 18.8508 0.0508 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 18.7375 0.0509 sec/batch
# Nearest to four: amphibian, reassigned, conclusion, hill, afvs, unger, stumbling, mise,
# Nearest to called: tigers, jabr, argonauts, statistician, bujumbura, calligraphy, gbase, pantheists,
# Nearest to nine: nonaligned, deck, rabbi, strobed, dyslexia, blastoderm, misconduct, warszawa,
# Nearest to first: karabakh, hmmwvs, absurdum, heligoland, celibate, alexandrine, spymaster, gbc,
# Nearest to these: encountering, aelius, cach, sectarian, cumin, supermodel, forgiving, purchased,
# Nearest to one: njimi, octet, budgeted, meritorious, conquer, aquaria, authorship, skinny,
# Nearest to d: defiled, nether, migrant, pdpa, seres, boney, lambs, congregated,
# Nearest to an: responds, marcionism, magh, circularity, hacks, drawings, excised, tyrell,
# Nearest to accepted: elbl, elmo, cle, exxonmobil, governors, onion, rosetta, force,
# Nearest to grand: infiltrators, partying, cylindrical, dyce, hopeful, chapters, glitch, outgrown,
# Nearest to san: calixto, schawlow, punish, sugary, hitch, lust, bronte, prescriptive,
# Nearest to question: homo, hangout, templeton, endothermy, debugging, fiedler, melos, airplanes,
# Nearest to rise: subcultural, earning, armistead, faye, yaobang, zwi, amphibole, mediator,
# Nearest to heavy: bohdan, shaved, anticipates, premarital, encroachments, molding, cear, overworked,
# Nearest to assembly: holloway, yage, similarities, caesar, shelly, lysine, modems, antibacterial,
# Nearest to notes: beaumarchais, unaccounted, parodied, segmented, herse, showbiz, psychologists, sanctuary,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 18.6129 0.0520 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 18.4994 0.0508 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 18.3459 0.0508 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 18.2648 0.0507 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 18.1969 0.0509 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 17.9536 0.0507 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 17.8194 0.0508 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 17.8056 0.0506 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 17.6322 0.0508 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 17.5608 0.0509 sec/batch
# Nearest to four: reassigned, amphibian, conclusion, hill, mise, unger, afvs, shamanic,
# Nearest to called: tigers, jabr, pantheists, bujumbura, statistician, gbase, argonauts, calligraphy,
# Nearest to nine: nonaligned, rabbi, deck, strobed, blastoderm, warszawa, timely, ayman,
# Nearest to first: karabakh, hmmwvs, absurdum, heligoland, alexandrine, celibate, dimitris, gbc,
# Nearest to these: encountering, sectarian, cach, supermodel, aelius, forgiving, cumin, theories,
# Nearest to one: octet, budgeted, conquer, njimi, meritorious, aquaria, fal, authorship,
# Nearest to d: nether, defiled, pdpa, seres, migrant, boney, congregated, medved,
# Nearest to an: responds, magh, circularity, hacks, marcionism, gag, herself, puckett,
# Nearest to accepted: elbl, elmo, cle, onion, rosetta, exxonmobil, governors, arduous,
# Nearest to grand: infiltrators, partying, cylindrical, hopeful, dyce, chapters, forty, glitch,
# Nearest to san: calixto, sugary, hitch, lust, punish, prescriptive, schawlow, stockpiling,
# Nearest to question: hangout, homo, templeton, endothermy, debugging, diphthong, fiedler, melos,
# Nearest to rise: subcultural, earning, armistead, faye, myron, yaobang, amphibole, zwi,
# Nearest to heavy: bohdan, shaved, anticipates, molding, cear, encroachments, overworked, premarital,
# Nearest to assembly: holloway, yage, similarities, shelly, lysine, iea, violations, antibacterial,
# Nearest to notes: beaumarchais, showbiz, unaccounted, parodied, herse, segmented, psychologists, denoted,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 17.3581 0.0518 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 17.3198 0.0509 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 17.2052 0.0510 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 17.0227 0.0509 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 16.9795 0.0506 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 16.8498 0.0510 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 16.7352 0.0509 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 16.6340 0.0508 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 16.5554 0.0507 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 16.4317 0.0510 sec/batch
# Nearest to four: amphibian, conclusion, hill, reassigned, mise, shamanic, afvs, geochemistry,
# Nearest to called: jabr, pantheists, bujumbura, tigers, statistician, calligraphy, gbase, argonauts,
# Nearest to nine: rabbi, nonaligned, blastoderm, strobed, deck, fascination, warszawa, timely,
# Nearest to first: karabakh, hmmwvs, absurdum, heligoland, alexandrine, celibate, dimitris, committees,
# Nearest to these: encountering, sectarian, supermodel, cach, forgiving, aelius, thirty, cumin,
# Nearest to one: octet, budgeted, aquaria, conquer, meritorious, njimi, industrialization, authorship,
# Nearest to d: nether, defiled, pdpa, migrant, seres, medved, boney, dihedral,
# Nearest to an: responds, circularity, magh, hacks, gag, marcionism, puckett, lip,
# Nearest to accepted: elbl, elmo, governors, cle, tame, arduous, rosetta, exxonmobil,
# Nearest to grand: infiltrators, partying, forty, cylindrical, hopeful, dyce, chapters, outgrown,
# Nearest to san: calixto, lust, sugary, hitch, punish, convinced, prescriptive, stockpiling,
# Nearest to question: homo, hangout, debugging, templeton, endothermy, diphthong, biographie, plugs,
# Nearest to rise: subcultural, earning, armistead, faye, zwi, yaobang, myron, amphibole,
# Nearest to heavy: bohdan, shaved, molding, anticipates, cear, encroachments, premarital, overworked,
# Nearest to assembly: holloway, yage, lysine, similarities, shelly, iea, antibacterial, jag,
# Nearest to notes: showbiz, parodied, heralds, beaumarchais, psychologists, unaccounted, rethink, herse,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 16.3342 0.0521 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 16.1745 0.0508 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 16.0736 0.0507 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 15.9278 0.0506 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 15.8884 0.0510 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 15.8528 0.0510 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 15.7336 0.0509 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 15.6748 0.0508 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 15.5193 0.0507 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 15.3310 0.0507 sec/batch
# Nearest to four: hill, amphibian, reassigned, shamanic, afvs, mise, conclusion, accumulated,
# Nearest to called: jabr, pantheists, bujumbura, statistician, tigers, calligraphy, hydrohalic, argonauts,
# Nearest to nine: rabbi, warszawa, strobed, nonaligned, timely, dyslexia, extractive, ayman,
# Nearest to first: karabakh, hmmwvs, absurdum, alexandrine, heligoland, dimitris, upload, interviewer,
# Nearest to these: encountering, sectarian, cach, supermodel, forgiving, thirty, urbane, aelius,
# Nearest to one: octet, salinity, budgeted, exhortations, meritorious, stature, conquer, fal,
# Nearest to d: nether, defiled, pdpa, migrant, medved, seres, dihedral, attractive,
# Nearest to an: circularity, responds, gag, hacks, magh, banned, bent, malaise,
# Nearest to accepted: elbl, elmo, tame, cle, emanated, arduous, rosetta, specificities,
# Nearest to grand: infiltrators, forty, hopeful, partying, cylindrical, dyce, outgrown, chapters,
# Nearest to san: calixto, lust, sugary, convinced, hitch, stockpiling, schwerin, punish,
# Nearest to question: homo, hangout, endothermy, debugging, templeton, diphthong, arena, hardwoods,
# Nearest to rise: subcultural, armistead, zwi, faye, yaobang, earning, pennock, myron,
# Nearest to heavy: bohdan, cear, molding, anticipates, shaved, premarital, grossed, mik,
# Nearest to assembly: holloway, yage, iea, lysine, studded, way, antibacterial, shelly,
# Nearest to notes: showbiz, parodied, beaumarchais, tributes, heralds, unaccounted, rethink, psychologists,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 15.3370 0.0516 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 15.2024 0.0508 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 15.1058 0.0510 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 15.0297 0.0509 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 14.8749 0.0510 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 14.8911 0.0510 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 14.7298 0.0377 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 14.5800 0.0510 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 14.4822 0.0509 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 14.3241 0.0508 sec/batch
# Nearest to four: hill, shamanic, levelling, inconclusive, accumulated, to, rovers, uncanonical,
# Nearest to called: jabr, pantheists, bujumbura, statistician, calligraphy, hydrohalic, marvellous, orchestra,
# Nearest to nine: warszawa, rabbi, strobed, ayman, dyslexia, nonaligned, rhead, beirut,
# Nearest to first: karabakh, hmmwvs, absurdum, upload, committees, maximus, alexandrine, tcm,
# Nearest to these: encountering, cach, sectarian, supermodel, thirty, coluim, urbane, bologna,
# Nearest to one: with, the, salinity, charlestown, banu, hilversum, phosphine, platform,
# Nearest to d: defiled, nether, pdpa, migrant, atlantean, attractive, reach, medved,
# Nearest to an: responds, magh, lip, gag, bent, circularity, banned, largest,
# Nearest to accepted: elmo, elbl, tame, cle, emanated, rosetta, specificities, arduous,
# Nearest to grand: infiltrators, forty, cylindrical, hopeful, dyce, partying, outgrown, discredit,
# Nearest to san: calixto, lust, convinced, sugary, hitch, stockpiling, schwerin, punish,
# Nearest to question: homo, hangout, endothermy, debugging, templeton, hardwoods, diphthong, moroccans,
# Nearest to rise: subcultural, armistead, zwi, faye, earning, yaobang, pennock, ij,
# Nearest to heavy: bohdan, cear, molding, shaved, anticipates, grossed, premarital, shooting,
# Nearest to assembly: holloway, unopposed, lysine, antibacterial, disambiguation, iea, jag, shelly,
# Nearest to notes: showbiz, beaumarchais, parodied, tributes, psychologists, stomach, heralds, rethink,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 14.4120 0.0519 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 14.2319 0.0509 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 14.0014 0.0514 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 13.9592 0.0508 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 13.9324 0.0508 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 13.8801 0.0509 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 13.6690 0.0508 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 13.5884 0.0507 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 13.5504 0.0509 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 13.5931 0.0504 sec/batch
# Nearest to four: and, one, in, zero, of, a, the, with,
# Nearest to called: jabr, pantheists, bujumbura, calligraphy, statistician, marvellous, bering, collins,
# Nearest to nine: two, eight, one, that, and, five, warszawa, zero,
# Nearest to first: karabakh, the, was, wu, a, alexandrine, absurdum, returns,
# Nearest to these: cach, encountering, sectarian, bologna, supermodel, thirty, moriarty, beano,
# Nearest to one: the, in, zero, with, and, to, five, two,
# Nearest to d: nether, defiled, pdpa, migrant, attractive, reach, atlantean, respects,
# Nearest to an: and, the, a, of, for, in, to, that,
# Nearest to accepted: elmo, elbl, tame, cle, emanated, candy, rosetta, governors,
# Nearest to grand: infiltrators, dyce, partying, hopeful, forty, cylindrical, outgrown, discredit,
# Nearest to san: calixto, convinced, lust, stockpiling, hitch, toy, entitlement, prescriptive,
# Nearest to question: hangout, homo, templeton, endothermy, airplanes, debugging, delivery, diphthong,
# Nearest to rise: zwi, earning, armistead, subcultural, faye, ij, absolutely, domicile,
# Nearest to heavy: bohdan, cear, molding, shaved, anticipates, grossed, ivar, shooting,
# Nearest to assembly: holloway, lysine, unopposed, iea, antibacterial, disambiguation, studded, potencies,
# Nearest to notes: beaumarchais, showbiz, parodied, heralds, stomach, psychologists, sanctuary, rethink,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 13.5445 0.0518 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 13.3306 0.0509 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 13.2529 0.0508 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 13.2194 0.0507 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 13.1560 0.0506 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 13.0514 0.0511 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 12.7844 0.0507 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 12.9381 0.0507 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 12.8140 0.0508 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 12.6848 0.0507 sec/batch
# Nearest to four: one, two, zero, five, nine, eight, s, six,
# Nearest to called: jabr, collins, forged, colours, walvis, on, letitia, these,
# Nearest to nine: one, five, eight, zero, two, four, s, six,
# Nearest to first: and, was, a, the, is, two, as, five,
# Nearest to these: bologna, supermodel, encountering, called, cach, amigaos, beano, acetate,
# Nearest to one: two, four, five, zero, nine, eight, s, in,
# Nearest to d: nether, defiled, pdpa, reach, migrant, attractive, s, envelope,
# Nearest to an: the, of, a, in, and, it, is, by,
# Nearest to accepted: elmo, elbl, tame, cle, emanated, governors, candy, carboxyl,
# Nearest to grand: infiltrators, forty, dyce, partying, hopeful, cylindrical, chapters, discredit,
# Nearest to san: calixto, convinced, lust, stockpiling, toy, prescriptive, entitlement, hitch,
# Nearest to question: homo, hangout, templeton, endothermy, airplanes, delivery, arena, hardwoods,
# Nearest to rise: earning, armistead, zwi, subcultural, pennock, ij, absolutely, singled,
# Nearest to heavy: bohdan, molding, cear, shaved, grossed, anticipates, shooting, ivar,
# Nearest to assembly: holloway, unopposed, iea, lysine, studded, way, shelly, jag,
# Nearest to notes: beaumarchais, showbiz, parodied, denoted, sanctuary, stomach, herse, humanist,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 12.8031 0.0517 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 12.5899 0.0508 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 12.3196 0.0509 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 12.4839 0.0507 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 12.3853 0.0508 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 12.2605 0.0509 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 12.2173 0.0512 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 12.2226 0.0509 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 11.9381 0.0510 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 11.9321 0.0506 sec/batch
# Nearest to four: one, five, six, zero, three, two, nine, eight,
# Nearest to called: as, on, the, have, of, a, and, early,
# Nearest to nine: one, five, eight, two, six, seven, three, four,
# Nearest to first: on, in, the, a, is, this, which, was,
# Nearest to these: with, not, which, has, as, for, on, of,
# Nearest to one: nine, eight, five, two, four, six, three, zero,
# Nearest to d: defiled, nether, pdpa, migrant, reach, envelope, slated, carolla,
# Nearest to an: the, is, of, with, in, to, not, and,
# Nearest to accepted: elmo, elbl, cle, emanated, tame, mysticeti, carboxyl, disdained,
# Nearest to grand: infiltrators, forty, dyce, partying, chapters, hopeful, discredit, planar,
# Nearest to san: calixto, convinced, stockpiling, lust, toy, prescriptive, hitch, schwerin,
# Nearest to question: arena, templeton, delivery, airplanes, homo, debugging, movers, endothermy,
# Nearest to rise: earning, armistead, zwi, supplies, subcultural, singled, absolutely, ij,
# Nearest to heavy: bohdan, molding, shaved, grossed, cear, shooting, ivar, anticipates,
# Nearest to assembly: holloway, iea, lysine, unopposed, studded, potencies, disambiguation, antibacterial,
# Nearest to notes: beaumarchais, showbiz, parodied, brash, herse, heralds, denoted, sardaukar,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 11.8232 0.0520 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 11.9855 0.0511 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 11.8251 0.0510 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 11.8323 0.0507 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 11.7872 0.0507 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 11.5377 0.0508 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 11.7736 0.0505 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 11.5244 0.0507 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 11.3109 0.0510 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 11.3810 0.0509 sec/batch
# Nearest to four: six, one, three, five, two, seven, eight, nine,
# Nearest to called: of, a, in, as, to, have, it, with,
# Nearest to nine: one, eight, six, seven, two, five, three, four,
# Nearest to first: also, the, was, nine, one, in, after, is,
# Nearest to these: of, a, in, the, most, and, not, which,
# Nearest to one: nine, eight, six, seven, five, four, two, zero,
# Nearest to d: six, one, three, seven, nine, five, four, zero,
# Nearest to an: the, of, in, a, for, it, have, and,
# Nearest to accepted: elmo, elbl, emanated, adopted, tame, cle, force, carboxyl,
# Nearest to grand: infiltrators, forty, dyce, partying, chapters, hopeful, discredit, outgrown,
# Nearest to san: calixto, convinced, lust, stockpiling, features, cuzco, hitch, nonferrous,
# Nearest to question: arena, airplanes, language, movers, delivery, templeton, homo, declined,
# Nearest to rise: earning, supplies, armistead, singled, ij, notably, zwi, absolutely,
# Nearest to heavy: bohdan, molding, shooting, grossed, anticipates, shaved, establish, mik,
# Nearest to assembly: holloway, unopposed, lysine, iea, eggs, antibacterial, coburg, potencies,
# Nearest to notes: beaumarchais, showbiz, parodied, sardaukar, celebritarian, tributes, pioneers, denoted,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 11.4492 0.0519 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 11.2688 0.0509 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 11.2256 0.0239 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 11.0975 0.0508 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 11.1487 0.0509 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 11.0381 0.0509 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 10.9378 0.0509 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 10.9764 0.0508 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 10.6615 0.0507 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 10.5946 0.0508 sec/batch
# Nearest to four: eight, zero, one, two, three, five, nine, six,
# Nearest to called: a, be, in, is, that, than, it, can,
# Nearest to nine: one, two, eight, six, five, four, three, seven,
# Nearest to first: to, of, and, the, for, all, in, with,
# Nearest to these: are, for, in, be, that, to, the, of,
# Nearest to one: eight, nine, four, six, two, three, five, seven,
# Nearest to d: six, five, nine, seven, one, four, eight, zero,
# Nearest to an: and, to, for, the, of, are, or, as,
# Nearest to accepted: elmo, tame, elbl, emanated, cle, adopted, disdained, nearly,
# Nearest to grand: infiltrators, forty, dyce, partying, chapters, hizb, giga, centronics,
# Nearest to san: calixto, features, convinced, stockpiling, lust, treble, toy, entitlement,
# Nearest to question: arena, language, airplanes, movers, declined, versatile, couturat, templeton,
# Nearest to rise: earning, myron, singled, armistead, supplies, collaboration, subcultural, ij,
# Nearest to heavy: bohdan, establish, shooting, grossed, molding, overworked, mik, shaved,
# Nearest to assembly: unopposed, iea, mountaineering, coburg, holloway, disambiguation, antibacterial, eggs,
# Nearest to notes: parodied, showbiz, beaumarchais, denoted, sigmoid, pioneers, tributes, stomach,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 10.6069 0.0521 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 10.6455 0.0507 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 10.4479 0.0509 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 10.2665 0.0508 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 10.4042 0.0507 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 10.2884 0.0507 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 10.4776 0.0505 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 10.3592 0.0507 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 10.1353 0.0509 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 10.2041 0.0507 sec/batch
# Nearest to four: three, zero, seven, eight, five, one, nine, two,
# Nearest to called: is, the, in, be, can, that, to, which,
# Nearest to nine: one, eight, zero, seven, three, two, four, five,
# Nearest to first: the, of, in, and, to, a, had, as,
# Nearest to these: the, as, some, is, of, and, for, not,
# Nearest to one: nine, eight, seven, zero, four, three, six, two,
# Nearest to d: one, nine, six, five, eight, seven, four, two,
# Nearest to an: the, in, and, as, a, to, of, only,
# Nearest to accepted: nearly, beginning, among, rather, being, elbl, adopted, which,
# Nearest to grand: man, infiltrators, forty, dyce, chapters, partying, hizb, giga,
# Nearest to san: calixto, convinced, features, cuzco, treble, lust, sugary, perceiving,
# Nearest to question: declined, language, arena, news, might, airplanes, towards, infringe,
# Nearest to rise: late, earning, supplies, begun, singled, absolutely, higher, yet,
# Nearest to heavy: bohdan, shooting, establish, grossed, ivar, cromarty, mik, overworked,
# Nearest to assembly: unopposed, mountaineering, resurfaces, iea, coburg, eggs, holloway, hosting,
# Nearest to notes: showbiz, beaumarchais, abdulaziz, parodied, bronstein, transactions, sardaukar, lis,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 10.1927 0.0518 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 10.1259 0.0508 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 9.7692 0.0515 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 9.8977 0.0510 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 9.9261 0.0509 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 9.7776 0.0508 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 9.7208 0.0510 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 9.9574 0.0506 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 9.5300 0.0509 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 9.6917 0.0508 sec/batch
# Nearest to four: one, six, five, two, three, nine, zero, seven,
# Nearest to called: is, the, but, of, with, used, a, in,
# Nearest to nine: one, five, six, eight, seven, four, two, three,
# Nearest to first: the, a, of, and, as, this, in, s,
# Nearest to these: this, is, of, a, are, it, to, have,
# Nearest to one: nine, eight, five, six, two, three, four, seven,
# Nearest to d: seven, six, one, eight, nine, american, five, three,
# Nearest to an: a, and, by, of, the, is, all, with,
# Nearest to accepted: many, but, so, other, men, are, less, nearly,
# Nearest to grand: forty, infiltrators, chapters, man, dyce, saskatchewan, partying, seven,
# Nearest to san: convinced, calixto, cuzco, city, treble, immediately, guarantee, cardiovascular,
# Nearest to question: taken, it, day, because, might, world, language, seen,
# Nearest to rise: more, based, especially, this, groups, either, designed, various,
# Nearest to heavy: shooting, grossed, device, overworked, bohdan, cromarty, ivar, establish,
# Nearest to assembly: eggs, unopposed, topic, coburg, resurfaces, plato, antibacterial, mountaineering,
# Nearest to notes: knows, whole, played, of, made, able, story, uk,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 9.7219 0.0519 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 9.5079 0.0509 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 9.5432 0.0508 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 9.6078 0.0509 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 9.3496 0.0509 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 9.2800 0.0506 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 9.2147 0.0509 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 9.4984 0.0509 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 9.2635 0.0509 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 9.1855 0.0509 sec/batch
# Nearest to four: seven, six, nine, one, zero, three, eight, five,
# Nearest to called: is, or, all, this, they, by, given, only,
# Nearest to nine: one, seven, eight, six, four, two, five, zero,
# Nearest to first: was, in, during, the, s, of, to, had,
# Nearest to these: the, have, or, a, has, in, this, is,
# Nearest to one: seven, eight, six, nine, five, four, zero, three,
# Nearest to d: one, american, eight, seven, nine, six, b, three,
# Nearest to an: the, of, to, a, and, is, in, has,
# Nearest to accepted: this, in, many, for, by, would, were, and,
# Nearest to grand: forty, infiltrators, dyce, encouraged, chapters, saskatchewan, hizb, figaro,
# Nearest to san: convinced, cuzco, front, calixto, at, immediately, city, guarantee,
# Nearest to question: it, not, about, second, when, only, might, very,
# Nearest to rise: from, began, were, has, other, about, especially, the,
# Nearest to heavy: shooting, establish, grossed, device, listed, feudalism, cromarty, enhanced,
# Nearest to assembly: eggs, topic, antibacterial, resurfaces, authority, molecules, plato, coburg,
# Nearest to notes: whole, important, until, based, frequently, able, noted, story,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 9.4873 0.0518 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 8.9163 0.0509 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 9.3048 0.0506 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 9.1575 0.0506 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 8.8526 0.0508 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 9.0100 0.0509 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 8.9922 0.0509 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 8.9726 0.0508 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 8.9110 0.0102 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 8.8159 0.0508 sec/batch
# Nearest to four: two, one, three, six, seven, eight, zero, five,
# Nearest to called: to, this, or, not, of, an, case, as,
# Nearest to nine: one, eight, seven, six, two, five, four, three,
# Nearest to first: in, the, on, as, was, to, and, of,
# Nearest to these: of, to, in, that, for, also, this, all,
# Nearest to one: eight, nine, four, five, seven, three, two, six,
# Nearest to d: american, b, french, nine, one, eight, seven, born,
# Nearest to an: of, to, the, this, in, and, a, is,
# Nearest to accepted: with, that, of, to, for, would, are, it,
# Nearest to grand: wife, published, she, reached, forty, television, major, study,
# Nearest to san: convinced, children, city, short, stability, at, addition, five,
# Nearest to question: become, by, an, for, to, the, of, which,
# Nearest to rise: has, the, and, same, largely, since, to, that,
# Nearest to heavy: device, shooting, led, listed, protect, off, may, up,
# Nearest to assembly: political, elected, president, january, change, government, popular, authority,
# Nearest to notes: whole, written, first, to, all, described, book, for,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 8.8149 0.0521 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 8.9135 0.0509 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 8.6727 0.0508 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 8.8287 0.0507 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 8.5377 0.0509 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 8.5096 0.0509 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 8.5061 0.0507 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 8.5595 0.0509 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 8.5112 0.0508 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 8.1234 0.0509 sec/batch
# Nearest to four: two, one, five, zero, seven, six, eight, nine,
# Nearest to called: a, of, is, be, that, or, to, the,
# Nearest to nine: one, eight, two, six, four, seven, five, zero,
# Nearest to first: the, s, to, in, was, of, it, and,
# Nearest to these: not, or, a, it, are, to, the, and,
# Nearest to one: two, nine, eight, four, six, five, zero, three,
# Nearest to d: b, american, french, born, eight, nine, english, one,
# Nearest to an: to, the, it, be, is, of, in, a,
# Nearest to accepted: it, the, there, to, all, of, is, both,
# Nearest to grand: she, grew, at, woman, were, reached, first, gave,
# Nearest to san: top, city, move, lost, the, after, settled, by,
# Nearest to question: of, by, people, influence, it, but, as, that,
# Nearest to rise: of, the, to, in, is, which, were, there,
# Nearest to heavy: up, increased, difficult, self, they, wide, and, recent,
# Nearest to assembly: members, political, government, elected, president, state, appointed, support,
# Nearest to notes: of, was, all, eight, s, next, the, second,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 8.2596 0.0519 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 8.2829 0.0508 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 8.4337 0.0510 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 8.3970 0.0507 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 8.0989 0.0508 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 8.1909 0.0508 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 8.2273 0.0508 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 8.3246 0.0507 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 7.9393 0.0511 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 8.0566 0.0511 sec/batch
# Nearest to four: five, one, six, zero, three, seven, nine, two,
# Nearest to called: to, of, a, in, and, that, the, is,
# Nearest to nine: one, eight, seven, four, six, five, three, two,
# Nearest to first: in, the, of, on, was, by, as, and,
# Nearest to these: the, as, a, this, of, it, for, on,
# Nearest to one: nine, three, four, seven, two, five, six, eight,
# Nearest to d: american, seven, eight, one, b, nine, author, german,
# Nearest to an: to, a, the, is, or, for, that, and,
# Nearest to accepted: as, it, the, and, there, of, this, in,
# Nearest to grand: she, gave, title, published, guide, home, famous, wrote,
# Nearest to san: settled, city, york, leading, remained, south, century, new,
# Nearest to question: the, it, that, to, not, be, some, many,
# Nearest to rise: that, a, and, as, were, to, their, in,
# Nearest to heavy: that, necessary, increased, down, year, large, many, free,
# Nearest to assembly: elected, government, national, president, appointed, authority, general, members,
# Nearest to notes: in, the, but, with, and, of, several, pre,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 8.0960 0.0519 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 7.9749 0.0507 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 7.9770 0.0510 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 8.1145 0.0506 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 7.7856 0.0509 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 7.7330 0.0509 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 8.0043 0.0510 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 7.7711 0.0509 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 7.8144 0.0509 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 7.8552 0.0509 sec/batch
# Nearest to four: one, five, seven, three, nine, two, eight, six,
# Nearest to called: an, and, for, to, as, of, the, in,
# Nearest to nine: one, eight, seven, five, four, two, three, six,
# Nearest to first: and, of, also, in, the, on, was, from,
# Nearest to these: for, the, to, an, of, this, are, a,
# Nearest to one: four, eight, nine, five, three, seven, two, in,
# Nearest to d: american, b, nine, john, eight, one, born, seven,
# Nearest to an: the, and, to, of, that, in, this, by,
# Nearest to accepted: has, of, as, countries, an, political, may, these,
# Nearest to grand: she, place, title, seven, man, five, april, was,
# Nearest to san: city, british, from, association, until, began, named, after,
# Nearest to question: it, because, rather, only, for, these, good, is,
# Nearest to rise: in, and, of, the, on, for, more, about,
# Nearest to heavy: performance, to, would, world, came, though, as, the,
# Nearest to assembly: elected, party, president, government, branch, minister, national, political,
# Nearest to notes: it, an, time, of, up, and, in, is,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 7.8288 0.0521 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 7.5036 0.0508 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 7.5667 0.0513 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 7.7407 0.0514 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 7.7144 0.0510 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 7.6663 0.0508 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 7.8930 0.0508 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 7.3950 0.0508 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 7.6520 0.0506 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 7.7417 0.0506 sec/batch
# Nearest to four: six, three, eight, five, two, one, seven, nine,
# Nearest to called: a, to, the, be, there, that, for, is,
# Nearest to nine: one, eight, three, two, seven, six, four, five,
# Nearest to first: the, was, in, on, of, and, from, s,
# Nearest to these: not, is, are, for, be, to, that, which,
# Nearest to one: eight, six, nine, seven, two, three, four, five,
# Nearest to d: american, b, writer, actor, george, robert, one, eight,
# Nearest to an: the, for, and, a, of, in, to, that,
# Nearest to accepted: of, to, the, in, by, would, from, on,
# Nearest to grand: two, three, nine, history, title, eight, uk, home,
# Nearest to san: city, york, america, at, officially, new, town, britain,
# Nearest to question: same, it, does, to, not, way, as, for,
# Nearest to rise: in, and, the, western, from, with, were, came,
# Nearest to heavy: only, wide, than, areas, made, to, rest, the,
# Nearest to assembly: elected, party, executive, government, elections, representatives, council, general,
# Nearest to notes: the, of, a, in, for, and, on, it,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 7.3320 0.0517 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 7.4771 0.0510 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 7.4830 0.0507 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 7.5002 0.0510 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 7.5905 0.0509 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 7.3076 0.0473 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 7.3740 0.0509 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 7.4595 0.0508 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 7.3486 0.0509 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 7.4236 0.0509 sec/batch
# Nearest to four: one, two, six, zero, five, three, eight, seven,
# Nearest to called: an, are, these, to, or, use, is, with,
# Nearest to nine: one, seven, eight, six, american, four, five, three,
# Nearest to first: in, s, the, of, early, at, to, for,
# Nearest to these: it, or, to, for, are, this, not, the,
# Nearest to one: eight, nine, six, seven, three, five, four, two,
# Nearest to d: b, american, writer, poet, actor, composer, nine, musician,
# Nearest to an: to, for, this, the, a, it, or, is,
# Nearest to accepted: not, for, the, that, to, s, both, were,
# Nearest to grand: home, record, won, britain, london, victory, city, s,
# Nearest to san: city, francisco, moved, america, california, u, after, national,
# Nearest to question: not, no, as, an, what, that, so, follow,
# Nearest to rise: in, the, to, between, of, for, least, with,
# Nearest to heavy: which, include, range, for, high, front, between, relatively,
# Nearest to assembly: elected, government, elections, election, political, council, branch, party,
# Nearest to notes: in, claims, least, and, the, book, of, to,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 7.2678 0.0519 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 7.1539 0.0507 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 7.2050 0.0506 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 7.2201 0.0510 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 7.2172 0.0510 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 6.9211 0.0509 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 6.9423 0.0507 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 7.0555 0.0510 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 7.1271 0.0507 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 7.1867 0.0507 sec/batch
# Nearest to four: eight, seven, zero, three, one, two, six, nine,
# Nearest to called: is, a, which, be, other, the, an, or,
# Nearest to nine: one, eight, six, zero, seven, four, three, two,
# Nearest to first: and, on, the, their, in, s, of, a,
# Nearest to these: to, are, and, that, as, a, of, have,
# Nearest to one: eight, six, zero, nine, three, two, four, five,
# Nearest to d: writer, b, poet, american, author, actor, william, composer,
# Nearest to an: of, the, a, and, which, with, as, that,
# Nearest to accepted: some, no, not, there, within, of, as, which,
# Nearest to grand: one, royal, eight, city, october, britain, took, world,
# Nearest to san: francisco, california, eight, nine, city, four, america, one,
# Nearest to question: such, this, some, of, nature, no, others, have,
# Nearest to rise: and, from, in, of, as, the, have, has,
# Nearest to heavy: to, the, main, large, but, air, into, and,
# Nearest to assembly: elected, elections, legislative, representatives, branch, parliament, executive, legislation,
# Nearest to notes: and, from, the, by, in, about, other, to,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 6.9516 0.0520 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 6.9517 0.0508 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 7.0261 0.0508 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 7.1406 0.0506 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 6.9376 0.0508 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 6.7277 0.0508 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 6.8989 0.0508 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 6.9601 0.0508 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 6.8187 0.0509 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 6.9734 0.0505 sec/batch
# Nearest to four: two, zero, five, three, one, seven, six, nine,
# Nearest to called: is, a, an, only, the, with, for, there,
# Nearest to nine: one, eight, six, seven, five, three, american, two,
# Nearest to first: and, the, at, s, on, in, was, by,
# Nearest to these: for, of, this, which, that, the, a, is,
# Nearest to one: eight, seven, nine, six, two, three, five, four,
# Nearest to d: american, b, actor, writer, one, poet, eight, nine,
# Nearest to an: a, for, of, is, to, the, this, it,
# Nearest to accepted: of, not, the, which, their, this, many, it,
# Nearest to grand: world, was, year, new, history, royal, had, began,
# Nearest to san: francisco, california, city, home, moved, november, street, named,
# Nearest to question: it, that, of, the, what, this, which, to,
# Nearest to rise: with, they, in, of, from, as, that, to,
# Nearest to heavy: down, small, apart, up, around, into, high, end,
# Nearest to assembly: legislative, elected, elections, branch, government, representatives, constitution, national,
# Nearest to notes: in, of, an, early, the, and, for, at,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 6.7230 0.0520 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 6.6629 0.0508 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 6.8584 0.0508 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 6.7752 0.0509 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 6.7509 0.0509 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 6.7582 0.0507 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 6.8250 0.0508 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 6.4211 0.0510 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 6.6165 0.0509 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 6.5695 0.0511 sec/batch
# Nearest to four: one, six, eight, five, three, nine, zero, two,
# Nearest to called: as, a, the, an, this, from, so, and,
# Nearest to nine: one, eight, seven, six, five, four, american, three,
# Nearest to first: s, the, and, on, during, at, was, new,
# Nearest to these: is, the, or, are, which, to, have, this,
# Nearest to one: eight, nine, five, seven, six, four, three, two,
# Nearest to d: american, b, writer, actor, nine, composer, poet, one,
# Nearest to an: a, the, for, this, by, to, as, is,
# Nearest to accepted: the, of, in, to, has, their, would, and,
# Nearest to grand: america, s, september, national, royal, family, august, five,
# Nearest to san: francisco, california, city, home, moved, named, former, london,
# Nearest to question: whether, this, that, what, be, or, knowledge, those,
# Nearest to rise: from, in, and, of, the, become, with, on,
# Nearest to heavy: than, major, small, high, the, for, well, large,
# Nearest to assembly: elected, legislative, representatives, elections, government, constitution, vote, election,
# Nearest to notes: both, a, time, all, for, and, well, this,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 6.7695 0.0522 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 6.6614 0.0510 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 6.8133 0.0509 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 6.6817 0.0508 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 6.4928 0.0508 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 6.7341 0.0506 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 6.5614 0.0507 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 6.4524 0.0508 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 6.4546 0.0509 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 6.6002 0.0508 sec/batch
# Nearest to four: eight, one, two, three, six, five, zero, seven,
# Nearest to called: is, or, a, to, this, that, the, because,
# Nearest to nine: one, eight, seven, five, american, two, six, four,
# Nearest to first: was, second, new, s, in, after, the, th,
# Nearest to these: that, be, is, to, this, a, for, have,
# Nearest to one: nine, eight, seven, five, six, two, four, three,
# Nearest to d: b, writer, american, politician, composer, poet, physicist, musician,
# Nearest to an: the, to, a, for, that, this, of, all,
# Nearest to accepted: not, of, were, while, the, that, and, was,
# Nearest to grand: national, york, new, crown, april, royal, world, september,
# Nearest to san: francisco, california, america, city, york, los, historic, county,
# Nearest to question: not, whether, does, do, that, some, how, notion,
# Nearest to rise: the, of, but, largely, with, however, and, some,
# Nearest to heavy: down, around, less, up, large, the, relatively, a,
# Nearest to assembly: elected, legislative, vote, elections, seats, cabinet, branch, representatives,
# Nearest to notes: writing, early, and, history, in, from, of, the,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 6.6274 0.0518 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 6.5116 0.0336 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 6.4562 0.0513 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 6.5660 0.0510 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 6.4549 0.0509 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 6.4726 0.0509 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 6.5143 0.0508 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 6.3005 0.0511 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 6.3187 0.0510 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 6.3444 0.0508 sec/batch
# Nearest to four: six, two, three, eight, five, one, zero, seven,
# Nearest to called: a, an, is, not, same, generally, be, or,
# Nearest to nine: one, eight, six, seven, two, four, three, american,
# Nearest to first: s, in, the, was, and, on, time, a,
# Nearest to these: are, or, because, any, be, such, is, an,
# Nearest to one: eight, nine, seven, three, six, four, two, five,
# Nearest to d: politician, writer, b, poet, composer, actor, physicist, musician,
# Nearest to an: a, of, for, be, which, to, the, and,
# Nearest to accepted: the, social, claimed, describe, not, of, criticism, and,
# Nearest to grand: s, was, england, one, home, last, february, history,
# Nearest to san: francisco, california, county, city, five, los, three, america,
# Nearest to question: that, do, statement, would, but, fact, say, as,
# Nearest to rise: its, the, but, of, to, and, this, in,
# Nearest to heavy: to, large, relatively, up, down, along, weapons, several,
# Nearest to assembly: legislative, elected, elections, parliamentary, constitution, constitutional, cabinet, executive,
# Nearest to notes: of, and, short, in, work, collection, writing, s,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 6.4378 0.0519 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 6.1408 0.0509 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 6.0919 0.0508 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 6.2139 0.0508 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 6.2816 0.0506 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 6.3835 0.0505 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 6.2127 0.0509 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 6.2279 0.0507 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 6.1314 0.0509 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 6.2774 0.0507 sec/batch
# Nearest to four: two, five, seven, six, zero, eight, three, one,
# Nearest to called: is, a, some, that, of, this, all, it,
# Nearest to nine: eight, seven, six, one, three, four, five, two,
# Nearest to first: and, by, the, of, after, on, had, s,
# Nearest to these: this, be, they, that, may, such, are, is,
# Nearest to one: eight, seven, three, nine, six, four, two, five,
# Nearest to d: b, american, one, physicist, composer, seven, writer, eight,
# Nearest to an: a, which, is, of, this, and, in, that,
# Nearest to accepted: of, according, view, however, some, modern, in, not,
# Nearest to grand: polish, queen, england, history, title, british, prince, oldest,
# Nearest to san: francisco, california, county, los, bay, york, five, town,
# Nearest to question: do, argue, not, indeed, nothing, agree, whether, what,
# Nearest to rise: and, in, from, of, been, but, were, is,
# Nearest to heavy: large, air, small, relatively, smaller, range, supply, mounted,
# ...
# Nearest to rise: from, near, which, in, the, around, and, between,
# Nearest to heavy: up, enemy, mounted, weapons, sides, trapped, large, cut,
# Nearest to assembly: legislative, branch, elected, elections, executive, constitutional, constitution, legislature,
# Nearest to notes: origins, history, english, writing, introduction, published, and, reading,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.9272 0.0519 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.9083 0.0508 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.9724 0.0508 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.9890 0.0509 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 5.0433 0.0507 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.9542 0.0509 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 5.0009 0.0508 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.9506 0.0506 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 5.0921 0.0507 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 5.0497 0.0506 sec/batch
# Nearest to four: two, five, three, eight, six, one, seven, zero,
# Nearest to called: is, a, only, an, be, unique, or, which,
# Nearest to nine: eight, seven, one, six, american, two, five, three,
# Nearest to first: s, the, in, second, was, and, on, after,
# Nearest to these: are, be, such, or, not, some, have, as,
# Nearest to one: eight, three, seven, two, six, five, four, nine,
# Nearest to d: b, physicist, one, laureate, eight, chemist, seven, mathematician,
# Nearest to an: a, this, of, be, the, for, to, or,
# Nearest to accepted: according, scholars, regarding, traditions, historical, others, religious, society,
# Nearest to grand: england, prince, title, village, famous, london, era, sydney,
# Nearest to san: francisco, california, jose, angeles, los, diego, oakland, bay,
# Nearest to question: not, questions, sense, those, nature, necessarily, whether, topic,
# Nearest to rise: and, from, recent, especially, in, vast, outside, of,
# Nearest to heavy: weight, tanks, air, tank, heavier, weapons, lighter, firing,
# Nearest to assembly: legislative, elected, elections, branch, parliament, legislature, parliamentary, representatives,
# Nearest to notes: writing, letters, history, origins, written, also, sounds, introduction,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.8821 0.0519 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.9661 0.0508 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 5.0443 0.0507 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.8934 0.0509 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 5.0540 0.0507 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.9220 0.0511 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.8492 0.0510 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 5.0034 0.0508 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.9911 0.0509 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.9274 0.0510 sec/batch
# Nearest to four: one, five, three, eight, seven, two, six, zero,
# Nearest to called: a, is, which, of, as, all, it, important,
# Nearest to nine: eight, one, seven, five, two, six, three, four,
# Nearest to first: s, on, was, at, of, time, in, the,
# Nearest to these: as, or, not, a, be, is, all, within,
# Nearest to one: eight, seven, five, four, two, nine, three, six,
# Nearest to d: b, physicist, eight, seven, chemist, laureate, american, one,
# Nearest to an: a, and, of, this, to, as, by, for,
# Nearest to accepted: religious, rejected, debate, considered, historians, matters, contrary, those,
# Nearest to grand: sydney, city, s, memorial, retirement, new, won, england,
# Nearest to san: francisco, jose, california, oakland, los, city, park, angeles,
# Nearest to question: whether, questions, do, notion, existence, does, that, interpret,
# Nearest to rise: and, in, world, throughout, from, about, of, at,
# Nearest to heavy: ground, heavier, lighter, tank, high, rapidly, vehicles, tanks,
# Nearest to assembly: legislative, elected, parliamentary, elections, branch, constitution, executive, constitutional,
# Nearest to notes: modern, style, writing, here, introduction, translated, origins, see,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.9475 0.0518 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.9878 0.0508 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.7850 0.0509 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.8421 0.0507 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.8633 0.0510 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.9442 0.0512 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.9900 0.0511 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 5.0859 0.0510 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 5.0423 0.0508 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.8444 0.0508 sec/batch
# Nearest to four: six, eight, one, three, two, seven, five, zero,
# Nearest to called: the, is, of, and, which, this, only, important,
# Nearest to nine: one, four, six, three, seven, eight, zero, two,
# Nearest to first: was, in, on, at, after, new, by, the,
# Nearest to these: be, are, within, through, this, other, is, that,
# Nearest to one: eight, four, six, nine, seven, three, two, five,
# Nearest to d: b, physicist, composer, writer, politician, laureate, poet, painter,
# Nearest to an: a, and, on, for, of, the, to, with,
# Nearest to accepted: according, regarding, religious, that, historians, scholars, believe, those,
# Nearest to grand: home, sydney, york, world, thirteen, opens, england, city,
# Nearest to san: francisco, california, jose, los, diego, home, angeles, oakland,
# Nearest to question: questions, notion, answer, arguments, does, whether, necessarily, what,
# Nearest to rise: and, western, over, from, in, substantial, of, rising,
# Nearest to heavy: ground, small, air, heavier, weather, off, mm, metal,
# Nearest to assembly: legislative, elected, elections, parliamentary, legislature, seats, constitution, council,
# Nearest to notes: origins, see, introduction, classical, translated, style, letters, article,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.9671 0.0517 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.9146 0.0507 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.8183 0.0512 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.8420 0.0514 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.8868 0.0508 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.9597 0.0509 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.9045 0.0295 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.8620 0.0510 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.8833 0.0510 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.8936 0.0509 sec/batch
# Nearest to four: five, three, two, zero, six, seven, eight, one,
# Nearest to called: or, is, which, are, example, it, thus, a,
# Nearest to nine: one, eight, seven, five, three, american, six, two,
# Nearest to first: on, s, second, two, three, next, time, in,
# Nearest to these: some, or, are, to, such, is, other, which,
# Nearest to one: eight, seven, five, nine, three, six, two, four,
# Nearest to d: b, laureate, physicist, writer, poet, eight, composer, seven,
# Nearest to an: for, with, as, more, to, it, all, is,
# Nearest to accepted: scholars, view, that, as, idea, believe, question, not,
# Nearest to grand: charlotte, victories, duke, one, victory, retirement, titles, england,
# Nearest to san: francisco, jose, california, diego, angeles, los, opens, santa,
# Nearest to question: questions, argues, arguments, nothing, idea, philosophical, what, views,
# Nearest to rise: most, between, in, which, relatively, around, large, over,
# Nearest to heavy: off, fire, ground, cold, up, air, exposed, down,
# Nearest to assembly: legislative, elections, elected, representatives, seats, branch, constitution, parliamentary,
# Nearest to notes: described, music, see, historical, collection, works, history, guide,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.8384 0.0519 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.9124 0.0508 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.8114 0.0510 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.7790 0.0509 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.8108 0.0509 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.8592 0.0507 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.7765 0.0509 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.6402 0.0511 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.7303 0.0510 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.7758 0.0508 sec/batch
# Nearest to four: six, seven, three, eight, five, one, zero, two,
# Nearest to called: is, that, or, the, these, a, which, an,
# Nearest to nine: one, eight, zero, six, four, seven, three, five,
# Nearest to first: was, on, in, following, second, time, s, after,
# Nearest to these: as, or, is, such, different, which, the, of,
# Nearest to one: eight, six, seven, three, four, nine, five, zero,
# Nearest to d: physicist, b, scientist, astronomer, mathematician, laureate, composer, poet,
# Nearest to an: for, a, the, be, that, as, which, of,
# Nearest to accepted: the, origin, view, of, which, according, believed, been,
# Nearest to grand: city, victories, memorial, duke, retirement, charlotte, won, victory,
# Nearest to san: francisco, california, jose, angeles, los, santa, diego, railroad,
# Nearest to question: questions, understanding, reasoning, theories, whether, notion, concept, existence,
# Nearest to rise: in, and, of, large, between, from, gradually, vast,
# Nearest to heavy: tanks, tank, air, off, weapons, fire, armor, down,
# Nearest to assembly: legislative, elected, elections, branch, representatives, seats, members, vote,
# Nearest to notes: discussion, history, collection, include, see, musical, art, english,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.8279 0.0517 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.7726 0.0506 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.7712 0.0510 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.7595 0.0509 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.8182 0.0507 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.8700 0.0510 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.7344 0.0510 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.7126 0.0506 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.8338 0.0507 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.7032 0.0509 sec/batch
# Nearest to four: two, five, zero, seven, three, six, one, eight,
# Nearest to called: the, is, an, a, form, this, of, or,
# Nearest to nine: eight, one, seven, six, zero, two, five, four,
# Nearest to first: s, was, and, on, one, the, in, few,
# Nearest to these: a, the, is, of, other, to, this, or,
# Nearest to one: eight, nine, six, seven, two, five, three, four,
# Nearest to d: b, scientist, physicist, eight, one, laureate, chemist, j,
# Nearest to an: is, a, be, the, it, or, same, for,
# Nearest to accepted: of, not, as, non, however, within, or, this,
# Nearest to grand: british, city, england, royal, village, took, prix, championship,
# Nearest to san: francisco, california, jose, angeles, oakland, railroad, los, diego,
# Nearest to question: questions, whether, reasoning, knowledge, true, do, moral, answer,
# Nearest to rise: and, in, the, of, to, this, into, from,
# Nearest to heavy: tanks, heavier, air, fire, tank, lighter, off, down,
# Nearest to assembly: legislative, elected, elections, representatives, constitution, branch, seats, cabinet,
# Nearest to notes: external, history, articles, of, written, s, art, musical,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.7946 0.0520 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.7771 0.0507 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.6113 0.0510 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.7673 0.0509 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.8574 0.0507 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.6692 0.0509 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.7067 0.0508 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.7766 0.0509 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.6752 0.0508 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.6330 0.0507 sec/batch
# Nearest to four: six, three, one, five, two, eight, seven, zero,
# Nearest to called: as, the, these, are, of, into, is, which,
# Nearest to nine: eight, seven, one, five, three, four, zero, two,
# Nearest to first: time, s, on, by, was, a, at, the,
# Nearest to these: the, of, or, with, which, some, and, through,
# Nearest to one: four, three, two, six, eight, five, seven, zero,
# Nearest to d: b, physicist, j, scientist, american, chemist, composer, statesman,
# Nearest to an: a, for, of, the, and, with, this, which,
# Nearest to accepted: claim, scholars, religious, christians, regarding, christian, influence, regarded,
# Nearest to grand: city, village, won, carolina, championships, memorial, home, san,
# Nearest to san: francisco, jose, california, los, angeles, antonio, city, diego,
# Nearest to question: questions, whether, moral, what, view, knowledge, understand, answer,
# Nearest to rise: and, from, in, has, economic, with, major, including,
# Nearest to heavy: heavier, air, metal, ground, tank, off, tanks, down,
# Nearest to assembly: legislative, elected, elections, representatives, branch, vote, constitution, election,
# Nearest to notes: note, tonal, written, english, writing, separate, letters, reference,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.6929 0.0520 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.7129 0.0509 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.7456 0.0509 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.8005 0.0508 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.9183 0.0509 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.6386 0.0509 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.7778 0.0506 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.7650 0.0507 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.5875 0.0509 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.6859 0.0507 sec/batch
# Nearest to four: five, six, three, two, seven, one, eight, zero,
# Nearest to called: is, are, complex, can, this, form, example, which,
# Nearest to nine: one, seven, eight, six, four, five, two, american,
# Nearest to first: second, s, in, following, and, was, a, one,
# Nearest to these: be, that, this, have, are, or, thus, other,
# Nearest to one: eight, seven, nine, six, four, five, two, three,
# Nearest to d: b, politician, writer, poet, composer, laureate, one, statesman,
# Nearest to an: a, for, the, and, of, as, this, in,
# Nearest to accepted: regarding, rejected, scholars, considered, opposed, according, nonetheless, doctrines,
# Nearest to grand: village, charlotte, city, memorial, carolina, governor, championships, retirement,
# Nearest to san: francisco, jose, california, los, diego, angeles, oakland, opens,
# Nearest to question: questions, ought, idea, whether, moral, answer, how, morality,
# Nearest to rise: and, period, especially, from, of, gradually, most, importance,
# Nearest to heavy: metal, ground, off, heavier, air, back, cold, fire,
# Nearest to assembly: legislative, elected, elections, seats, vote, electoral, representatives, cabinet,
# Nearest to notes: letters, written, writing, historical, texts, etc, introduction, detailed,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.6857 0.0519 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.7007 0.0509 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/carnd/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
